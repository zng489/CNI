# %%
import os
import json
import re
# Path to the folder

file_path = r'C:\Users\PC\Desktop\mapeamento_adf\all_pipelines.json'
with open(file_path, 'r') as file:
    data = json.load(file)
    #print(data[0])
    word = 'org'
    layer = 'org_raw'

    result_list =
    for each_one in data:
        #print(each_one['name'])   
        word = 'org'
        layer = 'lnd_org'
        if each_one['name'].startswith(layer):
            #each_one
            #print(each_one['name'])
            name_pipeline = each_one.get('name', {})
            folder = each_one.get('properties', {}).get('folder', {}).get('name', {})
            bot_script = each_one.get('properties', {}).get('parameters', {}).get('bot', {}).get('defaultValue', {})
            print(name_pipeline)
            print(folder)

        dados = {
              'NAME_PIPELINE': name_pipeline,
              'FOLDER': folder,
              'BOT_SCRIPT_NAME': bot_script}
        
        result_list.append(dados)
        #if re.search(rf'\b{word}\b', str(x), re.IGNORECASE):
        #    print(x)
# Out:
# lnd_org_raw_censo_escolar
# lnd/crw/inep_censo_escolar
# lnd_org_raw_microdados_enem
# lnd/crw/inep_enem
# lnd_org_raw_enem_escola
# lnd/crw/inep_enem
# lnd_org_raw_saeb
# lnd/crw/inep_saeb
# lnd_org_raw_estrutura_territorial
# lnd/crw/ibge
# lnd_org_raw_estrutura_cnae
# lnd/crw/ibge
# lnd_org_raw_microdados_pnad
# lnd/crw/ibge
# lnd_org_raw_inse_nivel_socioeconomico
# lnd/crw/inse
# lnd_org_raw_ipca
# lnd/crw/ibge
# lnd_org_raw_estrutura_cbo
# lnd/crw/ibge
# lnd_org_raw_microdados_caged_ajustes
# lnd/crw/me
# lnd_org_raw_rais_estabelecimento
# lnd/crw/me
# lnd_org_raw_prova_brasil
# lnd/crw/prova_brasil
# lnd_org_raw_microdados_caged
# lnd/crw/me
# lnd_org_raw_ideb
# lnd/crw/ideb
# lnd_org_raw_inse_afd
# lnd/crw/inse
# lnd_org_raw_rais_vinculo
# lnd/crw/me
# lnd_org_raw_trello
# lnd/crw/trello
# lnd_org_raw_deflatores
# lnd/crw/ibge
# lnd_org_raw_scnt
# lnd/crw/ibge
# lnd_org_raw_inep_atu
# lnd/crw/inep_atu
# lnd_org_raw_inep_had
# lnd/crw/inep_had
# lnd_org_raw_inep_ird
# lnd/crw/inep_ird
# lnd_org_raw_tdi
# lnd/crw/inep_tdi
# lnd_org_raw_dsu
# lnd/crw/inep_dsu
# lnd_org_raw_inep_rmd
# lnd/crw/inep_rmd
# lnd_org_raw_catho_vagas
# lnd/crw/catho_vagas
# lnd_org_raw_vagascom_vagas
# lnd/crw/vagascom_vagas
# lnd_org_raw_infojobs_vagas
# lnd/crw/infojobs_vagas
# lnd_org_raw_vagascertas_vagas
# lnd/crw/vagascertas_vagas
# lnd_org_raw_ibge_pop_projetada
# lnd/crw/ibge_pop_projetada
# lnd_org_raw_ibge_pop_estimada
# lnd/crw/ibge_pop_estimada
# lnd_org_raw_ibge_pintec_tipo_programa
# lnd/crw/ibge_pintec_tipo_programa
# lnd_org_raw_ibge_pintec_org_mkt
# lnd/crw/ibge_pintec_org_mkt
# lnd_org_raw_ibge_pintec_bio_nano
# lnd/crw/ibge_pintec_bio_nano
# lnd_org_raw_inss_cat
# lnd/crw/inss
# lnd_org_raw_microdados_novo_caged
# lnd/crw/me
# lnd_org_raw_inep_iqes
# lnd/crw/inep_iqes
# lnd_org_raw_ibge_pintec_prob_obst
# lnd/crw/ibge_pintec_prop_obst
# lnd_org_raw_aneel_gera_energia_distrib
# lnd/crw/aneel
# lnd_org_raw_mec_pnp_ept
# lnd/crw/mec_pnp_ept
# lnd_org_raw_ibge_pintec_rel_coop_loc
# lnd/crw/ibge_pintec_rel_cool_loc
# lnd_org_raw_ibge_pintec_rel_coop
# lnd/crw/ibge_pintec_rel_coop
# lnd_org_raw_ibge_pintec_prod_vend_int
# lnd/crw/ibge_pintec_prod_vend_int
# lnd_org_raw_ms_sinan_acgr
# lnd/crw/ms_sinan_acgr
# lnd_org_raw_ms_sinan_canc
# lnd/crw/ms_sinan_canc
# lnd_org_raw_ibge_pintec_tipo_inov_proj
# lnd/crw/ibge_pintec_tipo_inov_proj
# lnd_org_raw_ms_sinan_acbi
# lnd/crw/ms_sinan_acbi
# lnd_org_raw_ms_sinan_derm
# lnd/crw/ms_sinan_derm
# lnd_org_raw_ibge_pintec_grau_nov_imp
# lnd/crw/ibge_pintec_grau_nov_imp
# lnd_org_raw_ibge_pintec_resp_imp
# lnd/crw/ibge_pintec_resp_imp
# lnd_org_raw_banco_mundial_indicadores_selecionados
# lnd/crw/banco_mundial
# lnd_org_raw_ocde_projecoes_economicas
# lnd/crw/ocde_projecoes_economicas
# lnd_org_raw_test
# test
# lnd_org_raw_ms_sinan_pair
# lnd/crw/ms_sinan_pair
# lnd_org_raw_fmi_proj
# lnd/crw/fmi_proj
# lnd_org_raw_ms_sinan_lerd
# lnd/crw/ms_sinan_lerd
# lnd_org_raw_ms_sinan_ment
# lnd/crw/ms_sinan_ment
# lnd_org_raw_ms_sinan_pneu
# lnd/crw/ms_sinan_pneu
# lnd_org_raw_ms_sinan_iexo
# lnd/crw/ms_sinan_iexo
# lnd_org_raw_ms_sinan_anim
# lnd/crw/ms_sinan_anim
# lnd_org_raw_mtp_aeat_motivo_div
# lnd/crw/mtp_aeat
# lnd_org_raw_mtp_aeat_motivo_class
# lnd/crw/mtp_aeat
# lnd_org_raw_mtp_aeat_conseq_div
# lnd/crw/mtp_aeat
# lnd_org_raw_mtp_aeat_motivo_cid
# lnd/crw/mtp_aeat
# lnd_org_raw_mtp_aeat_motivo_ida_sex
# lnd/crw/mtp_aeat
# lnd_org_raw_mtp_aeat_acid_obi_mun
# lnd/crw/mtp_aeat
# lnd_org_raw_mtp_aeat_conseq_clas
# lnd/crw/mtp_aeat
# lnd_org_raw_rfb_cno
# lnd/crw/rfb_cno__cadastro_nacional_de_obras
# lnd_org_raw_piaemp
# lnd/crw/ibge
# lnd_org_raw_banco_mundial_preco_commodity
# lnd/crw/banco_mundial
# lnd_org_raw_pimpf
# lnd/crw/ibge
# lnd_org_raw_ibge_ipp_cnae_div
# lnd/crw/ibge
# lnd_org_raw_fred_indicadores_selecionados
# lnd/crw/fred
# lnd_org_raw_piaemp_aquisicoes
# lnd/crw/ibge
# lnd_org_raw_worldsteel_indicadores_selecionados
# lnd/crw/worldsteel
# lnd_org_raw_aco_brasil_prod_aco_nacional
# lnd/crw/aco_brasil
# lnd_org_raw_pia_produto_vti
# lnd/crw/ibge
# lnd_org_raw_me_comex
# lnd/crw/me
# lnd_org_raw_rfb_cnpj_cadastro_empresa
# lnd/crw/rfb_cnpj
# lnd_org_raw_rfb_cnpj_cadastro_socio
# lnd/crw/rfb_cnpj
# lnd_org_raw_rfb_cnpj_tabelas_auxiliares
# lnd/crw/rfb_cnpj
# lnd_org_raw_iea_carvao_estatisticas
# lnd/crw/iea
# lnd_org_raw_rfb_cnpj_regime_tributario
# lnd/crw/rfb_cnpj
# lnd_org_raw_rfb_cnpj_cadastro_simples
# lnd/crw/rfb_cnpj
# lnd_org_raw_rfb_cnpj_cadastro_estbl
# lnd/crw/rfb_cnpj
# lnd_org_raw_ibge_pnadc_a_deflatores
# lnd/crw/ibge
# lnd_org_raw_pnadc_a_visita2
# lnd/crw/ibge
# lnd_org_raw_ibge_pnadc_a_visita1
# lnd/crw/ibge
# lnd_org_raw_ibge_pnadc_a_visita5
# lnd/crw/ibge
# lnd_org_raw_ms_sim
# lnd/crw/ms
# lnd_org_raw_ibge_pintec_tipo_programa_po
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_bio_nano_po
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_org_mkt_po
# lnd/crw/ibge
# lnd_org_raw_inguru
# lnd/crw/inguru
# lnd_org_raw_ibge_pnadc_a_trim4
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_rel_coop_po
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_prob_obst_po
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_prod_vend_int_po
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_rel_coop_loc_po
# lnd/crw/ibge
# lnd_org_raw_ms_sih_sp
# lnd/crw/ms
# lnd_org_raw_ibge_gini
# lnd/crw/oni/ibge
# lnd_org_raw_ms_sih_rd
# lnd/crw/ms
# lnd_org_raw_ipca_indice_desagregado
# lnd/crw/ibge
# lnd_org_raw_bacen_cotacao
# lnd/crw/oni/bacen
# lnd_org_raw_ibge_pintec_inov_prod_proces_cnae
# lnd/crw/ibge
# lnd_org_raw_sgf_projetos_inovacao
# lnd/crw/unitec
# lnd_org_raw_ibge_pintec_grau_nov_prod_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_proc_neg_func_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_grau_obst_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_n_grau_obst_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_prod_proc_disp_pd_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_prod_proc_rel_coop_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_prod_proc_evolu_disp_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_prod_proc_pd_ex_disp_cnae
# lnd/crw/ibge
# lnd_org_raw_ibge_pintec_efei_pand_rel_sust_cnae
# lnd/crw/ibge
# lnd_org_raw_euromonitor_marketsize
# lnd/crw/oni/euromonitor
# lnd_org_raw_mpt_sst_cat
# lnd/crw/oni/mpt
# lnd_org_raw_ibge_pnadc_a_trim2
# lnd/crw/oni/ibge
# lnd_org_raw_ibge_pintec_prod_proc_disp_pd_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_prod_proc_evolu_disp_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_inov_prod_proces_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_proc_neg_func_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_grau_nov_prod_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_n_grau_obst_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_n_prod_proc_pd_ex_disp_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_prod_proc_rel_coop_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_efei_pand_rel_sust_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ibge_pintec_grau_obst_po
# lnd/crw/oni/ibge/pintec
# lnd_org_raw_ipca_adb
# lnd/crw/ibge
# lnd_org_raw_rfb_cno_adb
# lnd/crw/rfb_cno__cadastro_nacional_de_obras
# lnd_org_raw_mte_rais_publica_estabelecimento
# lnd/crw/oni/mte
# lnd_org_raw_mpt_sst_beneficios
# lnd/crw/oni/mpt
# lnd_org_raw_mpt_sst_acidentometro
# lnd/crw/oni/mpt
# lnd_org_raw_mpt_sst_indicadores_br
# lnd/crw/oni/mpt
# lnd_org_raw_mpt_sst_indicadores_uf
# lnd/crw/oni/mpt
# lnd_org_raw_contratos
# lnd/crw/dem_contab
# lnd_org_raw_indicadores_gratuidade
# lnd/crw/dem_contab
# lnd_org_raw_gratuidade
# lnd/crw/dem_contab
# lnd_org_raw_execucao_orcamentaria
# lnd/crw/dem_contab
# lnd_org_raw_aneel_gera_energia_distrib_adb
# lnd_adb
# lnd_org_raw_mpt_sst_indicadores_mun
# lnd/crw/oni/mpt
# lnd_org_raw_camara_dep_dados_abertos_deputados
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_inse_nivel_socioeconomico_adb
# lnd_adb
# lnd_org_raw_camara_dep_dados_abertos_votacoes
# lnd/crw/oni/camara_dep
# lnd_org_raw_camara_dep_dados_abertos_eventos
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_camara_dep_dados_abertos_frentes_parlamentares
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_camara_dep_dados_abertos_proposicoes
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_camara_dep_dados_abertos_orgaos
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_iel_it_cnpq_contratacao_bolsista
# lnd/crw/iel_inova_talentos
# lnd_org_raw_iel_it_cnpq_submeter_projeto
# lnd/crw/iel_inova_talentos
# lnd_org_raw_iel_it_ipt_contratacao_bolsista
# lnd/crw/iel_inova_talentos
# lnd_org_raw_iel_it_inova_talentos_submeter_projeto
# lnd/crw/iel_inova_talentos
# lnd_org_raw_iel_it_inovaiel_contratacao_bolsista
# lnd/crw/iel_inova_talentos
# lnd_org_raw_iel_it_ipt_submeter_projeto
# lnd/crw/iel_inova_talentos
# lnd_org_raw_camara_dep_dados_abertos_atividade_parlamentar
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_camara_dep_dados_abertos_funcionarios
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_camara_dep_dados_abertos_tesauro
# lnd/crw/oni/camara_dep/dados_abertos
# lnd_org_raw_mpt_sst_indicadores_uni
# lnd/crw/oni/mpt
# lnd_org_raw_trello_list_checklist_adb
# lnd/crw/oni/trello
# lnd_org_raw_trello_customfields_adb
# lnd/crw/oni/trello
# lnd_org_raw_trello_enterprise_board_organizations_adb
# lnd/crw/oni/trello
# lnd_org_raw_trello_member_actions_card_adb
# lnd/crw/oni/trello
# lnd_org_raw_matriculas_tipo_2
# lnd/crw/datalake_sesi_senai/producao/PE
# lnd_org_raw_inep_icg
# lnd/crw/inep_icg
# lnd_org_raw_inep_taxa_rendimento
# lnd/crw/inep_taxa_rendimento
# lnd_org_raw_logs_adf
# lnd/crw/log_analytics
# lnd_org_raw_logs_blob_storage
# lnd/crw/log_analytics
# lnd_org_raw_un_comtrade_partner
# lnd/crw/oni/un_comtrade/partner
# lnd_org_raw_un_comtrade_reporter
# lnd/crw/oni/un_comtrade/reporter
# lnd_org_raw_un_comtrade_comer_wld_commodity_annual
# lnd/crw/oni/un_comtrade/comer_wld
# lnd_org_raw_un_comtrade_comer_wld_commodity_monthly
# lnd/crw/oni/un_comtrade/comer_wld
# lnd_org_raw_un_comtrade_comer_wld_service_annual
# lnd/crw/oni/un_comtrade/comer_wld
# lnd_org_raw_inpi_badepi_patentes
# lnd/crw/oni/inpi
# lnd_org_raw_bacen_estban_mensal_municipios
# lnd/crw/oni/bacen/estban_mensal
# lnd_org_raw_mcti_inovadata_companies
# lnd/crw/oni/mcti
# lnd_org_raw_abstartups_lista_startups
# lnd/crw/oni/abstartups
# lnd_org_raw_capes_publicacoes
# lnd/crw/oni/capes
# lnd_org_raw_anprotec_mapa_associados
# lnd/crw/oni/anprotec
# lnd_org_raw_capes_cursos_pos_graduacao
# lnd/crw/oni/capes
# lnd_org_raw_mcti_empresas_lei_do_bem
# lnd/crw/oni/mcti
# lnd_org_raw_bndes_operacoes_indiretas_automaticas
# lnd/crw/oni/bndes
# lnd_org_raw_cnpq_financiamento
# lnd/crw/oni/cnpq
# lnd_org_raw_bndes_operacoes_nao_automaticas
# lnd/crw/oni/bndes
# lnd_org_raw_cwts_top_10_publicacoes
# lnd/crw/oni/cwts
# "\n    for each_one in data:\n        #print(each_one['name'])   \n        layer = 'org_raw'\n        if each_one['name'].startswith(layer):\n            #each_one\n            #print(each_one['name'])\n            name_pipeline = each_one.get('name', {})\n            #folder = each_one.get('properties', {}).get('folder', {}).get('name', {})\n            #bot_script = each_one.get('properties', {}).get('parameters', {}).get('bot', {}).get('defaultValue', {})\n            print(name_pipeline)\n            #print(folder)\n\n            #dados = {\n            #    'NAME_PIPELINE': name_pipeline,\n            #    'FOLDER': folder,\n            #    'BOT_SCRIPT_NAME': bot_script}\n            \n            #result_list.append(dados)\n            #if re.search(rf'\x08{word}\x08', str(x), re.IGNORECASE):\n            #    print(x)\n"

# %%
import pandas as pd
df = pd.DataFrame(result_list)
df
# Out:
#                                          NAME_PIPELINE  \
# 0                            lnd_org_raw_censo_escolar
# 1                          lnd_org_raw_microdados_enem
# 2                              lnd_org_raw_enem_escola
# 3                                     lnd_org_raw_saeb
# 4                    lnd_org_raw_estrutura_territorial
# ..                                                 ...
# 180               lnd_org_raw_mcti_empresas_lei_do_bem
# 181  lnd_org_raw_bndes_operacoes_indiretas_automaticas
# 182                     lnd_org_raw_cnpq_financiamento
# 183        lnd_org_raw_bndes_operacoes_nao_automaticas
# 184                lnd_org_raw_cwts_top_10_publicacoes
#
#                          FOLDER                                BOT_SCRIPT_NAME
# 0    lnd/crw/inep_censo_escolar                          org_raw_censo_escolar
# 1             lnd/crw/inep_enem                        org_raw_microdados_enem
# 2             lnd/crw/inep_enem                            org_raw_enem_escola
# 3             lnd/crw/inep_saeb                                   org_raw_saeb
# 4                  lnd/crw/ibge                  org_raw_estrutura_territorial
# ..                          ...                                            ...
# 180            lnd/crw/oni/mcti               org_raw_mcti_empresas_lei_do_bem
# 181           lnd/crw/oni/bndes  org_raw_bndes_operacoes_indiretas_automaticas
# 182            lnd/crw/oni/cnpq                 org_lnd_raw_cnpq_financiamento
# 183           lnd/crw/oni/bndes        org_raw_bndes_operacoes_nao_automaticas
# 184            lnd/crw/oni/cwts                org_raw_cwts_top_10_publicacoes
#
# [185 rows x 3 columns]

# %%
import requests
import json
from urllib.parse import urlparse, parse_qs
import sys
import os
from datetime import datetime, time, timedelta
 
 
 
subscription_id = '3e3a21e3-9551-4945-8c46-c02f558392ce'
resource_group_name = 'bigdata'
factory_name = 'cnibigdatafactory'
 
api_version = '2018-06-01'
 
# URL base da API
base_url = f"https://management.azure.com/subscriptions/{subscription_id}/resourceGroups/{resource_group_name}/providers/Microsoft.DataFactory/factories/{factory_name}"
 


token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktRMnRBY3JFN2xCYVZWR0JtYzVGb2JnZEpvNCIsImtpZCI6IktRMnRBY3JFN2xCYVZWR0JtYzVGb2JnZEpvNCJ9.....Y0FpA9pLx1Q-YIAWnQtt_Qi0pMNB79HuyKWqGhYnxwiGXIpDtckXUdH7BaoPSfvDX-0txJ1I5JidmgZU3U1S0HDWclwIVeyvvTkT6QZEJfkz556hDD1hJVipCc2vE7a0zW2uWpAYqeIa7_koqEa-TEzEi16n8A8yP_szmhj4qFVx7dkIJODJyRQ_t5q36X-yBxYYp391Y9dl_Xo4eEIaQxAX2fDf4SQp3DJYDWgEz1z4DCUF5qNYpqt-4I19Uz_xffX1g3DNila6s7IBKP4RpqkUQkRhlaLqMnkN7wQs5mD8-pbO5DPeOH5pSz24rvjr7fyLETi2pvWddxAkNl8hJQ'

# Função para obter dados paginados
def get_all_pipelines_runs(token, payload):
    pipelines = []
    continuationToken = None
   
   
 
 
    while True:
        params = {
            'api-version': api_version
        }
        if continuationToken:
            params['$continuationToken'] = continuationToken
       
        # Cabeçalhos (substitua '<seu_token_de_acesso>' por seu token de acesso)
        headers = {
            'Authorization': f'Bearer {token}'
        }
 
 
        url = f"{base_url}/queryPipelineRuns"
        response = requests.post(url, headers=headers, json=payload, params=params, )
       
        if response.status_code == 200:
            data = response.json()
            pipelines.extend(data.get('value', []))
 
            # Verifica se há mais páginas
            nextLink = data.get('continuationToken')
           
            # Parse da URL para obter os parâmetros da query
            parsed_url = urlparse(nextLink)
            query_params = parse_qs(parsed_url.query)
 
            # Extrai o valor de $skipToken
            continuationToken = query_params.get('$token', [None])[0]
           
            if not continuationToken:
                break
        else:
            print(f"Erro {response.status_code}: {response.text}")
            break
   
    return pipelines
 
def main():
 
   
    #if len(sys.argv) != 2:
    #    print("Uso: python script.py <token oauth>")
    #    sys.exit(1)
    token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktRMnRBY3JFN2xCYVZWR0JtYzVGb2JnZEpvNCIsImtpZCI6IktRMnRBY3JFN2xCYVZWR0JtYzVGb2JnZEpvNCJ9.....Y0FpA9pLx1Q-YIAWnQtt_Qi0pMNB79HuyKWqGhYnxwiGXIpDtckXUdH7BaoPSfvDX-0txJ1I5JidmgZU3U1S0HDWclwIVeyvvTkT6QZEJfkz556hDD1hJVipCc2vE7a0zW2uWpAYqeIa7_koqEa-TEzEi16n8A8yP_szmhj4qFVx7dkIJODJyRQ_t5q36X-yBxYYp391Y9dl_Xo4eEIaQxAX2fDf4SQp3DJYDWgEz1z4DCUF5qNYpqt-4I19Uz_xffX1g3DNila6s7IBKP4RpqkUQkRhlaLqMnkN7wQs5mD8-pbO5DPeOH5pSz24rvjr7fyLETi2pvWddxAkNl8hJQ'

    #token = sys.argv[1]
   
    # Passo 1: Criar um objeto datetime com a data desejada
    data = datetime.now() - timedelta(days=1)  # Por exemplo, 20 de agosto de 2024
 
    # Passo 2: Adicionar o horário desejado
    # Criar um objeto time para o horário
    horaIni = time(00, 00, 00)  # 23:59:59
    horaFin = time(23, 59, 59)  # 23:59:59
 
    # Adicionar o horário à data
    lastUpdatedAfter = datetime.combine(data, horaIni).strftime('%Y-%m-%dT%H:%M:%SZ')
    lastUpdatedBefore = datetime.combine(data, horaFin).strftime('%Y-%m-%dT%H:%M:%SZ')
 
   
    payload = {
            "lastUpdatedAfter": lastUpdatedAfter,  # Ajuste a data conforme necessário
            "lastUpdatedBefore": lastUpdatedBefore,  # Ajuste a data conforme necessário
            "filters": [{
                "operand": "LatestOnly",
                "operator": "Equals",
                "values": ["true"]
                }
            ]
        }
    #"2024-08-14T00:00:00Z","2024-08-14T23:59:59Z"
    print (payload)
    token = token.replace("\r\n","")
 
    # Obtenha todos os pipelines
    all_pipelines = get_all_pipelines_runs(token, payload)
 
    # Partes do caminho
    #pasta = "C:\\tmp\\pipelines"
    arquivo = "get_all_pipelines_runs.json"
 
    # Caminho do arquivo onde o JSON será salvo
 
    #os.makedirs(pasta,exist_ok=True)
 
    #file_path = os.path.join(pasta,arquivo)
 
    # Salvando o JSON em um arquivo
    with open(arquivo, 'w') as json_file:
        json.dump(all_pipelines, json_file, indent=4)
 
    print(f"Dados salvos em {file_path}")
 
 
if __name__ == "__main__":
    main()
# Out:
# {'lastUpdatedAfter': '2024-08-20T00:00:00Z', 'lastUpdatedBefore': '2024-08-20T23:59:59Z', 'filters': [{'operand': 'LatestOnly', 'operator': 'Equals', 'values': ['true']}]}
# Dados salvos em C:\Users\PC\Desktop\mapeamento_adf\all_pipelines.json

# %%
import requests
from urllib.parse import urlparse, parse_qs
import json


subscription_id = '3e3a21e3-9551-4945-8c46-c02f558392ce'
resourceGroupName = 'bigdata'
factoryName = 'cnibigdatafactory'
api_version = '2018-06-01'
api_token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IktRMnRBY3JFN2xCYVZWR0JtYzVGb2JnZEpvNCIsImtpZCI6IktRMnRBY3JFN2xCYVZWR0JtYzVGb2JnZEpvNCJ9.....kPvw3-WvZfN2rK7XYwHRifow1iqUWjAPPt5IZYFlJqBcumYHuW608v0tVAOPwBQo2umOM8O-YVZqdPJf6KcD6_nUGpD1qwQEHR_e8beWh6HzMulHU1j797RXwUe77vp1XhFhwFz8kSvec1CIM6ccOhW6YXoVCIdQhcPauicagqx6fQdGKLLTcJDBLmQm53UZ4AF6aUeLAPP9vLffphi7EXAe7Gr5Q_Ad0lXpINXfO0IyWNOijoPvI7a6xO4Tz1tqCQ61eAuswXWdixoIrF16IGZZFTT5OKFUJhzqEW9r9ybTdz6NAK4OCN-Mu1utm4VvSg7sOY43r4Wsoc4Ark1FiQ'

url = f"https://management.azure.com/subscriptions/{subscription_id}/resourceGroups/{resourceGroupName}/providers/Microsoft.DataFactory/factories/{factoryName}/pipelines?api-version=2018-06-01"
#url =  'https://management.azure.com/subscriptions/3e3a21e3-9551-4945-8c46-c02f558392ce/resourceGroups/bigdata/
# providers/Microsoft.DataFactory/factories/cnibigdatafactory/pipelines?api-version=2018-06-01&$skipToken=%2bRID%3a~abc9AM0t8wBkIAAAAAAwCg%3d%3d%23RT%3a1%23TRC%3a50%23ISV%3a2%23IEO%3a65551%23QCF%3a8'
 
headers = {
    'Authorization': f'Bearer {api_token}'
}

def main():
    pipelines = []
    skip_token = None
    while True:
        params = {
        'api_version': api_token,
        '$skipToken': ''}
        if skip_token:
            params['$skipToken'] = skip_token
            
        response = requests.get(url, headers=headers, params=params )
        if  response.status_code == 200:
            print(response.status_code)
            data = response.json()
            pipelines.extend(data.get('value',[]))
            skip_toke_url = data.get('nextLink')
            if not skip_toke_url:
                break

            parsed_url = urlparse(skip_toke_url)
            query_params = parse_qs(parsed_url.query)

            skip_token = query_params.get('$skipToken', [None])[0]

        else:
            break
    
    return pipelines

    #print(response.status_code)
    #print(response.json())
    #print(response.json().get('nextLink'))
    ###parsed_url = urlparse(response.json().get('nextLink'))
    #print(parsed_url)
    ###query_params = parse_qs(parsed_url.query)
    #print(query_params)
    ###skip_token = query_params.get('$skipToken',[None])[0]
    #print(skip_token)

        #print(response.json()['value'][0])
    #skip_toke_url = response.json()[0].get('nextLink')

with open('all_pipelines.json', 'w') as json_file:
    json.dump(main(), json_file, indent=4)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
pipelines
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pipelines
#
# NameError: name 'pipelines' is not defined

# %%
query_params = {'$filter': 'name eq John'}
skip_token = query_params.get('$skipToken', [None])[0]
print(skip_token)  # Output: None (since $skipToken is not in query_params)
# Out:
# None

# %%
# Example dictionary
data = {
    'name': 'Alice',
    'age': 30,
    'hobbies': ['reading', 'hiking']
}

# Using .get() to safely retrieve a key's value
hobbies = data.get('hobbies', [])
print(hobbies)  # Output: ['reading', 'hiking']

# Trying to get a key that doesn't exist
favorite_foods = data.get('favorite_foods', [])
print(favorite_foods)  # Output: []
# Out:
# ['reading', 'hiking']
# []

# %%
import requests
import pandas as pd

class EnricherAPI:
    def _init_(self):
        self.base_url = "https://www.orulo.com.br/api/v2"
        url = "https://www.orulo.com.br/oauth/token"
        payload = "client_id=72b60287e126019aded565ce0914dec50867fcc7d9e27c585b9f20bdd517d93e&client_secret=591c8ec875285250f346f388b4b90d3fd88cc61795d2325fd53026f7936f2f0b&grant_type=client_credentials"
        headers = {
            "cookie": "AWSALB=Lnz8wbbwPXiUU9crYXGnAIdlu2byl81pMa6QSEuyPq76mA73Jc2mP%2FnYog7PLzhq9QiUsyiQ6dn%2F6G%2BFIoHbZc0fJaOA1snrp8Bhdm6HEanwOP0DaNzJsh%2B8v8%2B4; AWSALBCORS=Lnz8wbbwPXiUU9crYXGnAIdlu2byl81pMa6QSEuyPq76mA73Jc2mP%2FnYog7PLzhq9QiUsyiQ6dn%2F6G%2BFIoHbZc0fJaOA1snrp8Bhdm6HEanwOP0DaNzJsh%2B8v8%2B4; ahoy_visitor=3367b732-df29-455f-95db-5b05559b991f; ahoy_visit=859226e5-3030-4eb3-b815-3c05aca5f672",
            "Content-Type": "application/x-www-form-urlencoded"
        }
        response = requests.request("POST", url, data=payload, headers=headers)



    def get_building(self, page):
        url = f"{self.base_url}/buildings"
        
        payload = ""
        headers = {
            "cookie": "AWSALB=Lnz8wbbwPXiUU9crYXGnAIdlu2byl81pMa6QSEuyPq76mA73Jc2mP%2FnYog7PLzhq9QiUsyiQ6dn%2F6G%2BFIoHbZc0fJaOA1snrp8Bhdm6HEanwOP0DaNzJsh%2B8v8%2B4; AWSALBCORS=Lnz8wbbwPXiUU9crYXGnAIdlu2byl81pMa6QSEuyPq76mA73Jc2mP%2FnYog7PLzhq9QiUsyiQ6dn%2F6G%2BFIoHbZc0fJaOA1snrp8Bhdm6HEanwOP0DaNzJsh%2B8v8%2B4; ahoy_visitor=3367b732-df29-455f-95db-5b05559b991f; ahoy_visit=859226e5-3030-4eb3-b815-3c05aca5f672",
            "Content-Type": "multipart/form-data; boundary=---011000010111000001101001",
            "Authorization": "Bearer 1chb1napGZV_3xyb9zvpfql25ubE900YqGpkKPvID4o"
        }
        params = {
            "page": page
        }

        response = requests.request("GET", url, data=payload, headers=headers, params=params)
        # print(response.text)

        if response.status_code == 200:
            return response.json()
        else:
            print(f"Erro na requisição: {response.status_code}")
            return None

enricher = EnricherAPI()
page = 1
data = []
while True:
    file = enricher.get_building(page=page)
    if file is not None:
        data = []
        for building in file["buildings"]:
            address_orulo = building["address"]
            address_string = f"{address_orulo.get('street', '')} {address_orulo.get('number', '')}, {address_orulo.get('neighborhood', '')}, {address_orulo.get('city', '')} - {address_orulo.get('state', '')}"  # cria a string do endereço no formato "1600 Pennsylvania Avenue NW, Washington, DC"
            response = requests.get("https://nominatim.openstreetmap.org/search?format=json&q=" + address_string)
            if response.status_code == 200:
                response_json = response.json()
                if len(response_json) > 0:
                    latitude = response_json[0]["lat"]
                    longitude = response_json[0]["lon"]
                    data.append({
                        "orulo_address": address_orulo,
                        "osm_address": {
                            "latitude": latitude,
                            "longitude": longitude
                        }
                    })
                print(f"{address_string} - Latitude: {latitude}, Longitude: {longitude}")

        page += 1
        if page > file["total_pages"]:
            break

df = pd.DataFrame(data)
df.to_csv("buildings.csv",index=False)

# %%
def main():
